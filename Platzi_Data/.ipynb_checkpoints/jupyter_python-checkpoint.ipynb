# %%
import pandas as pd
pd.options.display.max_rows = 10

el_tiempo = pd.read_csv('eltiempo_2020_01_17_articles.csv')

el_tiempo
# Out:
#                                                  body  \
# 0   \n\n\n\nCon casi 10 meses de vida, Guadalupe M...
# 1   \n\n\n\nEl fotógrafo boyacense Fernando Bello ...
# 2   \n\n\n\nLos poderes psicodélicos de la ayahuas...
# 3   \n\n\n\nCada vez más dólares, cada vez menos b...
# 4   \n\n\n\nVaqueros de Montería conquistó el títu...
# ..                                                ...
# 49  \n\n\n\n“Iba caminado cerca a los dormitorios....
# 50  \n\n\n\n“Maduro se ha convertido en metáfora d...
# 51  \n\n\n\nElegir el tiquete o vuelo ideal, ahora...
# 52  \n\n\n\nIván Cancino, abogado del empresario A...
# 53  \n\n\n\nEl conductor de un taxi que en la madr...
#
#                                                 title  \
# 0   El cadete que murió a sus 22 años sin conocer ...
# 1   Fotógrafo reportado como desaparecido fue roba...
# 2   'Fui abusada sexualmente por un chamán en un r...
# 3   ¿De dónde salen los dólares en Venezuela que d...
# 4   Vaqueros, campeón de la Liga profesional de bé...
# ..                                                ...
# 49  Habla un sobreviviente del atentado en la Gene...
# 50                                                NaN
# 51  Socios LifeMiles podrán guardar la tarifa en m...
# 52  'Sanmiguel no dijo que plata de Odebrecht entr...
# 53  Taxista involucrado en accidente con motos est...
#
#                                                   url
# 0   https://www.eltiempo.com/justicia/investigacio...
# 1   https://www.eltiempo.com/colombia/otras-ciudad...
# 2   https://www.eltiempo.com/mundo/latinoamerica/f...
# 3   https://www.eltiempo.com/economia/sectores/ven...
# 4   https://www.eltiempo.com/deportes/otros-deport...
# ..                                                ...
# 49  https://www.eltiempo.com/justicia/investigacio...
# 50  https://www.eltiempo.com/opinion/columnistas/p...
# 51  https://www.eltiempo.com/contenido-comercial/s...
# 52  https://www.eltiempo.com/politica/partidos-pol...
# 53  https://www.eltiempo.com/bogota/taxista-involu...
#
# [54 rows x 3 columns]

# %%
# 2. Obtener el host
from urllib.parse import urlparse

el_tiempo['host'] = el_tiempo['url'].apply(lambda url: urlparse(url).netloc)

el_tiempo
# Out:
#                                                                                body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  \n\n\n\nCon casi 10 meses de vida, Guadalupe M...
# f12dd6ef27d51fdb7cbac996b4c12b61  \n\n\n\nEl fotógrafo boyacense Fernando Bello ...
# 3b6278887ba69216f9d98e2e3d5ae5a1  \n\n\n\nLos poderes psicodélicos de la ayahuas...
# e9f297f6da6826397729e5e278d2191c  \n\n\n\nCada vez más dólares, cada vez menos b...
# 7fd5d6a25e9786c91ea74fc881e987e5  \n\n\n\nVaqueros de Montería conquistó el títu...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  \n\n\n\n“Iba caminado cerca a los dormitorios....
# d72ec81a9813daf8aa7c2a9756528255  \n\n\n\n“Maduro se ha convertido en metáfora d...
# 33ee739117ed28f116619c946865052a  \n\n\n\nElegir el tiquete o vuelo ideal, ahora...
# 22328ec9dbb1d585ba3698eb472cfd67  \n\n\n\nIván Cancino, abogado del empresario A...
# 729431b4acfab2c7437be8d15cbb01b5  \n\n\n\nEl conductor de un taxi que en la madr...
#
#                                                                               title  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  El cadete que murió a sus 22 años sin conocer ...
# f12dd6ef27d51fdb7cbac996b4c12b61  Fotógrafo reportado como desaparecido fue roba...
# 3b6278887ba69216f9d98e2e3d5ae5a1  'Fui abusada sexualmente por un chamán en un r...
# e9f297f6da6826397729e5e278d2191c  ¿De dónde salen los dólares en Venezuela que d...
# 7fd5d6a25e9786c91ea74fc881e987e5  Vaqueros, campeón de la Liga profesional de bé...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  Habla un sobreviviente del atentado en la Gene...
# d72ec81a9813daf8aa7c2a9756528255                                                NaN
# 33ee739117ed28f116619c946865052a  Socios LifeMiles podrán guardar la tarifa en m...
# 22328ec9dbb1d585ba3698eb472cfd67  'Sanmiguel no dijo que plata de Odebrecht entr...
# 729431b4acfab2c7437be8d15cbb01b5  Taxista involucrado en accidente con motos est...
#
#                                                                                 url  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  https://www.eltiempo.com/justicia/investigacio...
# f12dd6ef27d51fdb7cbac996b4c12b61  https://www.eltiempo.com/colombia/otras-ciudad...
# 3b6278887ba69216f9d98e2e3d5ae5a1  https://www.eltiempo.com/mundo/latinoamerica/f...
# e9f297f6da6826397729e5e278d2191c  https://www.eltiempo.com/economia/sectores/ven...
# 7fd5d6a25e9786c91ea74fc881e987e5  https://www.eltiempo.com/deportes/otros-deport...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  https://www.eltiempo.com/justicia/investigacio...
# d72ec81a9813daf8aa7c2a9756528255  https://www.eltiempo.com/opinion/columnistas/p...
# 33ee739117ed28f116619c946865052a  https://www.eltiempo.com/contenido-comercial/s...
# 22328ec9dbb1d585ba3698eb472cfd67  https://www.eltiempo.com/politica/partidos-pol...
# 729431b4acfab2c7437be8d15cbb01b5  https://www.eltiempo.com/bogota/taxista-involu...
#
#                                               host  n_tokens_body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  www.eltiempo.com          292.0
# f12dd6ef27d51fdb7cbac996b4c12b61  www.eltiempo.com          128.0
# 3b6278887ba69216f9d98e2e3d5ae5a1  www.eltiempo.com         1245.0
# e9f297f6da6826397729e5e278d2191c  www.eltiempo.com          739.0
# 7fd5d6a25e9786c91ea74fc881e987e5  www.eltiempo.com           41.0
# ...                                            ...            ...
# 9407942b3dbcbf83639cf24f6a36f939  www.eltiempo.com          547.0
# d72ec81a9813daf8aa7c2a9756528255  www.eltiempo.com            NaN
# 33ee739117ed28f116619c946865052a  www.eltiempo.com          290.0
# 22328ec9dbb1d585ba3698eb472cfd67  www.eltiempo.com          153.0
# 729431b4acfab2c7437be8d15cbb01b5  www.eltiempo.com          120.0
#
#                                   n_tokens_title
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee             6.0
# f12dd6ef27d51fdb7cbac996b4c12b61             6.0
# 3b6278887ba69216f9d98e2e3d5ae5a1             5.0
# e9f297f6da6826397729e5e278d2191c             6.0
# 7fd5d6a25e9786c91ea74fc881e987e5             5.0
# ...                                          ...
# 9407942b3dbcbf83639cf24f6a36f939             5.0
# d72ec81a9813daf8aa7c2a9756528255             NaN
# 33ee739117ed28f116619c946865052a             8.0
# 22328ec9dbb1d585ba3698eb472cfd67             6.0
# 729431b4acfab2c7437be8d15cbb01b5             5.0
#
# [54 rows x 6 columns]

# %%
# 3. Rellenar datos faltantes

missing_titles_mask = el_tiempo['title'].isna()

missing_titles= (el_tiempo[missing_titles_mask]['url']
                 .str.extract(r'(?P<missing_titles>[^/]+)$')
                 .applymap(lambda title: title.split('-'))
                 .applymap(lambda title_word_list: ' '.join(title_word_list))
            )
missing_titles
# Out:
#                                                                      missing_titles
# uid
# 23de64571d42405170e32f7bf0a5af31  transicion energetica columna de manuel guzman...
# c5cf1985205ee78f9b67f86864501e9e  sabidurias ancestrales columna de moises wasse...
# 7d9da18b1c767ef823cd44a1ebeea0a7       animo columna de ricardo silva romero 452638
# 827eb389ce11d45ae09ea8736a360c76   la reforma del icetex editorial el tiempo 452682
# d72ec81a9813daf8aa7c2a9756528255  no olvidemos a venezuela columna de plinio apu...

# %%
# 4. Añadir uid a las filas
import hashlib

uids = (el_tiempo
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )

el_tiempo['uid'] = uids
el_tiempo.set_index('uid', inplace=True)

el_tiempo
# Out:
#                                                                                body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  \n\n\n\nCon casi 10 meses de vida, Guadalupe M...
# f12dd6ef27d51fdb7cbac996b4c12b61  \n\n\n\nEl fotógrafo boyacense Fernando Bello ...
# 3b6278887ba69216f9d98e2e3d5ae5a1  \n\n\n\nLos poderes psicodélicos de la ayahuas...
# e9f297f6da6826397729e5e278d2191c  \n\n\n\nCada vez más dólares, cada vez menos b...
# 7fd5d6a25e9786c91ea74fc881e987e5  \n\n\n\nVaqueros de Montería conquistó el títu...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  \n\n\n\n“Iba caminado cerca a los dormitorios....
# d72ec81a9813daf8aa7c2a9756528255  \n\n\n\n“Maduro se ha convertido en metáfora d...
# 33ee739117ed28f116619c946865052a  \n\n\n\nElegir el tiquete o vuelo ideal, ahora...
# 22328ec9dbb1d585ba3698eb472cfd67  \n\n\n\nIván Cancino, abogado del empresario A...
# 729431b4acfab2c7437be8d15cbb01b5  \n\n\n\nEl conductor de un taxi que en la madr...
#
#                                                                               title  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  El cadete que murió a sus 22 años sin conocer ...
# f12dd6ef27d51fdb7cbac996b4c12b61  Fotógrafo reportado como desaparecido fue roba...
# 3b6278887ba69216f9d98e2e3d5ae5a1  'Fui abusada sexualmente por un chamán en un r...
# e9f297f6da6826397729e5e278d2191c  ¿De dónde salen los dólares en Venezuela que d...
# 7fd5d6a25e9786c91ea74fc881e987e5  Vaqueros, campeón de la Liga profesional de bé...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  Habla un sobreviviente del atentado en la Gene...
# d72ec81a9813daf8aa7c2a9756528255                                                NaN
# 33ee739117ed28f116619c946865052a  Socios LifeMiles podrán guardar la tarifa en m...
# 22328ec9dbb1d585ba3698eb472cfd67  'Sanmiguel no dijo que plata de Odebrecht entr...
# 729431b4acfab2c7437be8d15cbb01b5  Taxista involucrado en accidente con motos est...
#
#                                                                                 url  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  https://www.eltiempo.com/justicia/investigacio...
# f12dd6ef27d51fdb7cbac996b4c12b61  https://www.eltiempo.com/colombia/otras-ciudad...
# 3b6278887ba69216f9d98e2e3d5ae5a1  https://www.eltiempo.com/mundo/latinoamerica/f...
# e9f297f6da6826397729e5e278d2191c  https://www.eltiempo.com/economia/sectores/ven...
# 7fd5d6a25e9786c91ea74fc881e987e5  https://www.eltiempo.com/deportes/otros-deport...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  https://www.eltiempo.com/justicia/investigacio...
# d72ec81a9813daf8aa7c2a9756528255  https://www.eltiempo.com/opinion/columnistas/p...
# 33ee739117ed28f116619c946865052a  https://www.eltiempo.com/contenido-comercial/s...
# 22328ec9dbb1d585ba3698eb472cfd67  https://www.eltiempo.com/politica/partidos-pol...
# 729431b4acfab2c7437be8d15cbb01b5  https://www.eltiempo.com/bogota/taxista-involu...
#
#                                               host  n_tokens_body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  www.eltiempo.com          292.0
# f12dd6ef27d51fdb7cbac996b4c12b61  www.eltiempo.com          128.0
# 3b6278887ba69216f9d98e2e3d5ae5a1  www.eltiempo.com         1245.0
# e9f297f6da6826397729e5e278d2191c  www.eltiempo.com          739.0
# 7fd5d6a25e9786c91ea74fc881e987e5  www.eltiempo.com           41.0
# ...                                            ...            ...
# 9407942b3dbcbf83639cf24f6a36f939  www.eltiempo.com          547.0
# d72ec81a9813daf8aa7c2a9756528255  www.eltiempo.com            NaN
# 33ee739117ed28f116619c946865052a  www.eltiempo.com          290.0
# 22328ec9dbb1d585ba3698eb472cfd67  www.eltiempo.com          153.0
# 729431b4acfab2c7437be8d15cbb01b5  www.eltiempo.com          120.0
#
#                                   n_tokens_title
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee             6.0
# f12dd6ef27d51fdb7cbac996b4c12b61             6.0
# 3b6278887ba69216f9d98e2e3d5ae5a1             5.0
# e9f297f6da6826397729e5e278d2191c             6.0
# 7fd5d6a25e9786c91ea74fc881e987e5             5.0
# ...                                          ...
# 9407942b3dbcbf83639cf24f6a36f939             5.0
# d72ec81a9813daf8aa7c2a9756528255             NaN
# 33ee739117ed28f116619c946865052a             8.0
# 22328ec9dbb1d585ba3698eb472cfd67             6.0
# 729431b4acfab2c7437be8d15cbb01b5             5.0
#
# [54 rows x 6 columns]

# %%
stripped_body = (el_tiempo
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                     .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee    Con casi 10 meses de vida, Guadalupe Manjarrez...
# f12dd6ef27d51fdb7cbac996b4c12b61    El fotógrafo boyacense Fernando Bello Mendoza,...
# 3b6278887ba69216f9d98e2e3d5ae5a1    Los poderes psicodélicos de la ayahuasca, una ...
# e9f297f6da6826397729e5e278d2191c    Cada vez más dólares, cada vez menos bolívares...
# 7fd5d6a25e9786c91ea74fc881e987e5    Vaqueros de Montería conquistó el título del b...
#                                                           ...
# 9407942b3dbcbf83639cf24f6a36f939    “Iba caminado cerca a los dormitorios. Observé...
# d72ec81a9813daf8aa7c2a9756528255    “Maduro se ha convertido en metáfora de la mue...
# 33ee739117ed28f116619c946865052a    Elegir el tiquete o vuelo ideal, ahora será mu...
# 22328ec9dbb1d585ba3698eb472cfd67    Iván Cancino, abogado del empresario Andrés Sa...
# 729431b4acfab2c7437be8d15cbb01b5    El conductor de un taxi que en la madrugada de...
# Length: 54, dtype: object

# %%
# 6. tenkenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

# nltk.download('punkt')
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
               .dropna()
               .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
               .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
               .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
               .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
               .apply(lambda valid_word_list : len(valid_word_list))
           )
el_tiempo['n_tokens_body'] = tokenize_column(el_tiempo, 'body')
el_tiempo['n_tokens_title'] = tokenize_column(el_tiempo, 'title')

el_tiempo
# Out:
#                                                  body  \
# 0   \n\n\n\nCon casi 10 meses de vida, Guadalupe M...
# 1   \n\n\n\nEl fotógrafo boyacense Fernando Bello ...
# 2   \n\n\n\nLos poderes psicodélicos de la ayahuas...
# 3   \n\n\n\nCada vez más dólares, cada vez menos b...
# 4   \n\n\n\nVaqueros de Montería conquistó el títu...
# ..                                                ...
# 49  \n\n\n\n“Iba caminado cerca a los dormitorios....
# 50  \n\n\n\n“Maduro se ha convertido en metáfora d...
# 51  \n\n\n\nElegir el tiquete o vuelo ideal, ahora...
# 52  \n\n\n\nIván Cancino, abogado del empresario A...
# 53  \n\n\n\nEl conductor de un taxi que en la madr...
#
#                                                 title  \
# 0   El cadete que murió a sus 22 años sin conocer ...
# 1   Fotógrafo reportado como desaparecido fue roba...
# 2   'Fui abusada sexualmente por un chamán en un r...
# 3   ¿De dónde salen los dólares en Venezuela que d...
# 4   Vaqueros, campeón de la Liga profesional de bé...
# ..                                                ...
# 49  Habla un sobreviviente del atentado en la Gene...
# 50                                                NaN
# 51  Socios LifeMiles podrán guardar la tarifa en m...
# 52  'Sanmiguel no dijo que plata de Odebrecht entr...
# 53  Taxista involucrado en accidente con motos est...
#
#                                                   url  n_tokens_body  \
# 0   https://www.eltiempo.com/justicia/investigacio...          292.0
# 1   https://www.eltiempo.com/colombia/otras-ciudad...          128.0
# 2   https://www.eltiempo.com/mundo/latinoamerica/f...         1245.0
# 3   https://www.eltiempo.com/economia/sectores/ven...          739.0
# 4   https://www.eltiempo.com/deportes/otros-deport...           41.0
# ..                                                ...            ...
# 49  https://www.eltiempo.com/justicia/investigacio...          547.0
# 50  https://www.eltiempo.com/opinion/columnistas/p...            NaN
# 51  https://www.eltiempo.com/contenido-comercial/s...          290.0
# 52  https://www.eltiempo.com/politica/partidos-pol...          153.0
# 53  https://www.eltiempo.com/bogota/taxista-involu...          120.0
#
#     n_tokens_title
# 0              6.0
# 1              6.0
# 2              5.0
# 3              6.0
# 4              5.0
# ..             ...
# 49             5.0
# 50             NaN
# 51             8.0
# 52             6.0
# 53             5.0
#
# [54 rows x 5 columns]

# %%
# 8. Eliminar duplicados

el_tiempo['title'].value_counts()
# Out:
# La reacción de Petro a la intervención del Esmad en la Nacional           1
# La desigualdad laboral para las madres / El peso político del #Megxit     1
# Cierre nocturno por 6 meses en vía a La Línea por terminación de túnel    1
# La misteriosa desaparición de madre e hija colombianas en Miami           1
# Alcaldesa Claudia López estrenó su protocolo para las marchas             1
#                                                                          ..
# Más de mil migrantes hondureños en camino a EE. UU. llegan a Guatemala    1
# ‘Sigue la epidemia de dengue y no podemos bajar los brazos’               1
# Refutan dictamen de Medicina Legal sobre muerte de universitaria          1
# Aparecen más pruebas de que Trump ‘vulneró la ley’                        1
# Taxista involucrado en accidente con motos estaría ebrio                  1
# Name: title, Length: 49, dtype: int64

# %%
el_tiempo[el_tiempo['title'] == 'Batallón de Ciberinteligencia volvió a ser inspeccionado']
# Out:
#                                                                                body  \
# uid
# c7543b2806144cef7eee90b451c82a32  \n\n\n\nAgentes especiales de la Procuraduría ...
#
#                                                                               title  \
# uid
# c7543b2806144cef7eee90b451c82a32  Batallón de Ciberinteligencia volvió a ser ins...
#
#                                                                                 url  \
# uid
# c7543b2806144cef7eee90b451c82a32  https://www.eltiempo.com/unidad-investigativa/...
#
#                                               host  n_tokens_body  \
# uid
# c7543b2806144cef7eee90b451c82a32  www.eltiempo.com          190.0
#
#                                   n_tokens_title
# uid
# c7543b2806144cef7eee90b451c82a32             5.0

# %%
el_tiempo
# Out:
#                                                                                body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  \n\n\n\nCon casi 10 meses de vida, Guadalupe M...
# f12dd6ef27d51fdb7cbac996b4c12b61  \n\n\n\nEl fotógrafo boyacense Fernando Bello ...
# 3b6278887ba69216f9d98e2e3d5ae5a1  \n\n\n\nLos poderes psicodélicos de la ayahuas...
# e9f297f6da6826397729e5e278d2191c  \n\n\n\nCada vez más dólares, cada vez menos b...
# 7fd5d6a25e9786c91ea74fc881e987e5  \n\n\n\nVaqueros de Montería conquistó el títu...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  \n\n\n\n“Iba caminado cerca a los dormitorios....
# d72ec81a9813daf8aa7c2a9756528255  \n\n\n\n“Maduro se ha convertido en metáfora d...
# 33ee739117ed28f116619c946865052a  \n\n\n\nElegir el tiquete o vuelo ideal, ahora...
# 22328ec9dbb1d585ba3698eb472cfd67  \n\n\n\nIván Cancino, abogado del empresario A...
# 729431b4acfab2c7437be8d15cbb01b5  \n\n\n\nEl conductor de un taxi que en la madr...
#
#                                                                               title  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  El cadete que murió a sus 22 años sin conocer ...
# f12dd6ef27d51fdb7cbac996b4c12b61  Fotógrafo reportado como desaparecido fue roba...
# 3b6278887ba69216f9d98e2e3d5ae5a1  'Fui abusada sexualmente por un chamán en un r...
# e9f297f6da6826397729e5e278d2191c  ¿De dónde salen los dólares en Venezuela que d...
# 7fd5d6a25e9786c91ea74fc881e987e5  Vaqueros, campeón de la Liga profesional de bé...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  Habla un sobreviviente del atentado en la Gene...
# d72ec81a9813daf8aa7c2a9756528255                                                NaN
# 33ee739117ed28f116619c946865052a  Socios LifeMiles podrán guardar la tarifa en m...
# 22328ec9dbb1d585ba3698eb472cfd67  'Sanmiguel no dijo que plata de Odebrecht entr...
# 729431b4acfab2c7437be8d15cbb01b5  Taxista involucrado en accidente con motos est...
#
#                                                                                 url  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  https://www.eltiempo.com/justicia/investigacio...
# f12dd6ef27d51fdb7cbac996b4c12b61  https://www.eltiempo.com/colombia/otras-ciudad...
# 3b6278887ba69216f9d98e2e3d5ae5a1  https://www.eltiempo.com/mundo/latinoamerica/f...
# e9f297f6da6826397729e5e278d2191c  https://www.eltiempo.com/economia/sectores/ven...
# 7fd5d6a25e9786c91ea74fc881e987e5  https://www.eltiempo.com/deportes/otros-deport...
# ...                                                                             ...
# 9407942b3dbcbf83639cf24f6a36f939  https://www.eltiempo.com/justicia/investigacio...
# d72ec81a9813daf8aa7c2a9756528255  https://www.eltiempo.com/opinion/columnistas/p...
# 33ee739117ed28f116619c946865052a  https://www.eltiempo.com/contenido-comercial/s...
# 22328ec9dbb1d585ba3698eb472cfd67  https://www.eltiempo.com/politica/partidos-pol...
# 729431b4acfab2c7437be8d15cbb01b5  https://www.eltiempo.com/bogota/taxista-involu...
#
#                                               host  n_tokens_body  \
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee  www.eltiempo.com          292.0
# f12dd6ef27d51fdb7cbac996b4c12b61  www.eltiempo.com          128.0
# 3b6278887ba69216f9d98e2e3d5ae5a1  www.eltiempo.com         1245.0
# e9f297f6da6826397729e5e278d2191c  www.eltiempo.com          739.0
# 7fd5d6a25e9786c91ea74fc881e987e5  www.eltiempo.com           41.0
# ...                                            ...            ...
# 9407942b3dbcbf83639cf24f6a36f939  www.eltiempo.com          547.0
# d72ec81a9813daf8aa7c2a9756528255  www.eltiempo.com            NaN
# 33ee739117ed28f116619c946865052a  www.eltiempo.com          290.0
# 22328ec9dbb1d585ba3698eb472cfd67  www.eltiempo.com          153.0
# 729431b4acfab2c7437be8d15cbb01b5  www.eltiempo.com          120.0
#
#                                   n_tokens_title
# uid
# 1e2d91aabf34cc31ae65facad37cb1ee             6.0
# f12dd6ef27d51fdb7cbac996b4c12b61             6.0
# 3b6278887ba69216f9d98e2e3d5ae5a1             5.0
# e9f297f6da6826397729e5e278d2191c             6.0
# 7fd5d6a25e9786c91ea74fc881e987e5             5.0
# ...                                          ...
# 9407942b3dbcbf83639cf24f6a36f939             5.0
# d72ec81a9813daf8aa7c2a9756528255             NaN
# 33ee739117ed28f116619c946865052a             8.0
# 22328ec9dbb1d585ba3698eb472cfd67             6.0
# 729431b4acfab2c7437be8d15cbb01b5             5.0
#
# [54 rows x 6 columns]
